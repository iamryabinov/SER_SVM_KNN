# %%
import pandas as pd

# %%
df = pd.read_csv('summarized_classification_reports.csv', delimiter=';')
df
# Out:
#             class  precision    recall  f1-score     classifier  \
# 0             neg   0.758065  0.924469  0.833038            KNN
# 1             not   0.691318  0.364407  0.477248            KNN
# 2       macro avg   0.724691  0.644438  0.655143            KNN
# 3    weighted avg   0.736904  0.746910  0.720240            KNN
# 4             ang   0.600515  0.732704  0.660057            KNN
# ..            ...        ...       ...       ...            ...
# 262           neu   0.990099  1.000000  0.995025  SVM_nonlinear
# 263           sad   0.990000  0.990000  0.990000  SVM_nonlinear
# 264           sur   0.970588  0.990000  0.980198  SVM_nonlinear
# 265     macro avg   0.987197  0.987143  0.987128  SVM_nonlinear
# 266  weighted avg   0.987197  0.987143  0.987128  SVM_nonlinear
#
#                     dataset
# 0    Crema-D-NegativeBinary
# 1    Crema-D-NegativeBinary
# 2    Crema-D-NegativeBinary
# 3    Crema-D-NegativeBinary
# 4                   Crema-D
# ...

# %%
df = df.loc[(df['classifier'] == 'SVM_nonlinear')]
df
# Out:
#             class  precision    recall  f1-score     classifier  \
# 178           neg   0.805596  0.860740  0.832256  SVM_nonlinear
# 179           not   0.648111  0.552542  0.596523  SVM_nonlinear
# 180     macro avg   0.726854  0.706641  0.714389  SVM_nonlinear
# 181  weighted avg   0.755668  0.763031  0.757520  SVM_nonlinear
# 182           ang   0.710914  0.757862  0.733638  SVM_nonlinear
# ..            ...        ...       ...       ...            ...
# 262           neu   0.990099  1.000000  0.995025  SVM_nonlinear
# 263           sad   0.990000  0.990000  0.990000  SVM_nonlinear
# 264           sur   0.970588  0.990000  0.980198  SVM_nonlinear
# 265     macro avg   0.987197  0.987143  0.987128  SVM_nonlinear
# 266  weighted avg   0.987197  0.987143  0.987128  SVM_nonlinear
#
#                     dataset
# 178  Crema-D-NegativeBinary
# 179  Crema-D-NegativeBinary
# 180  Crema-D-NegativeBinary
# 181  Crema-D-NegativeBinary
# 182                 Crema-D
# ...

# %%
df = df.drop(['classifier'], axis=1)
df
# Out:
#             class  precision    recall  f1-score                 dataset
# 178           neg   0.805596  0.860740  0.832256  Crema-D-NegativeBinary
# 179           not   0.648111  0.552542  0.596523  Crema-D-NegativeBinary
# 180     macro avg   0.726854  0.706641  0.714389  Crema-D-NegativeBinary
# 181  weighted avg   0.755668  0.763031  0.757520  Crema-D-NegativeBinary
# 182           ang   0.710914  0.757862  0.733638                 Crema-D
# ..            ...        ...       ...       ...                     ...
# 262           neu   0.990099  1.000000  0.995025                    TESS
# 263           sad   0.990000  0.990000  0.990000                    TESS
# 264           sur   0.970588  0.990000  0.980198                    TESS
# 265     macro avg   0.987197  0.987143  0.987128                    TESS
# 266  weighted avg   0.987197  0.987143  0.987128                    TESS
#
# [89 rows x 5 columns]

# %%
df.to_csv('svm_nonlinear_classification_reports.csv', sep=';', index=False)
