# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('classifiers\\knn\\knn_summarized_results_final.csv', delimiter=';')
df
# Out:
#                    dataset      method preprocessing  n_neighbors  \
# 0                  Iemocap  base-multi           raw            2
# 1                  Iemocap  base-multi           raw            3
# 2                  Iemocap  base-multi           raw            4
# 3                  Iemocap  base-multi           raw            5
# 4                  Iemocap  base-multi           raw            6
# ...                    ...         ...           ...          ...
# 4657  English-Assembly-Six      binary  standardized           71
# 4658  English-Assembly-Six      binary  standardized           72
# 4659  English-Assembly-Six      binary  standardized           73
# 4660  English-Assembly-Six      binary  standardized           74
# 4661  English-Assembly-Six      binary  standardized           75
#
#       train_score  test_score
# 0        0.634721    0.242059
# 1        0.565717    0.262322
# 2        0.544724    0.293538
# 3        0.516977    0.294633
# ...

# %%
df['subset'] = 'train'
df
# Out:
#                    dataset      method preprocessing  n_neighbors  \
# 0                  Iemocap  base-multi           raw            2
# 1                  Iemocap  base-multi           raw            3
# 2                  Iemocap  base-multi           raw            4
# 3                  Iemocap  base-multi           raw            5
# 4                  Iemocap  base-multi           raw            6
# ...                    ...         ...           ...          ...
# 4657  English-Assembly-Six      binary  standardized           71
# 4658  English-Assembly-Six      binary  standardized           72
# 4659  English-Assembly-Six      binary  standardized           73
# 4660  English-Assembly-Six      binary  standardized           74
# 4661  English-Assembly-Six      binary  standardized           75
#
#       train_score  test_score subset
# 0        0.634721    0.242059  train
# 1        0.565717    0.262322  train
# 2        0.544724    0.293538  train
# ...

# %%
df['score'] = df['train_score']
df
# Out:
#                    dataset      method preprocessing  n_neighbors  \
# 0                  Iemocap  base-multi           raw            2
# 1                  Iemocap  base-multi           raw            3
# 2                  Iemocap  base-multi           raw            4
# 3                  Iemocap  base-multi           raw            5
# 4                  Iemocap  base-multi           raw            6
# ...                    ...         ...           ...          ...
# 4657  English-Assembly-Six      binary  standardized           71
# 4658  English-Assembly-Six      binary  standardized           72
# 4659  English-Assembly-Six      binary  standardized           73
# 4660  English-Assembly-Six      binary  standardized           74
# 4661  English-Assembly-Six      binary  standardized           75
#
#       train_score  test_score subset     score
# 0        0.634721    0.242059  train  0.634721
# 1        0.565717    0.262322  train  0.565717
# ...

# %%
df.to_csv('classifiers\\knn\\_knn_summarized_results_final_train.csv', index=False, sep=';')

# %%
df
# Out:
#                    dataset      method preprocessing  n_neighbors  \
# 0                  Iemocap  base-multi           raw            2
# 1                  Iemocap  base-multi           raw            3
# 2                  Iemocap  base-multi           raw            4
# 3                  Iemocap  base-multi           raw            5
# 4                  Iemocap  base-multi           raw            6
# ...                    ...         ...           ...          ...
# 4657  English-Assembly-Six      binary  standardized           71
# 4658  English-Assembly-Six      binary  standardized           72
# 4659  English-Assembly-Six      binary  standardized           73
# 4660  English-Assembly-Six      binary  standardized           74
# 4661  English-Assembly-Six      binary  standardized           75
#
#       train_score  test_score subset     score
# 0        0.634721    0.242059  train  0.634721
# 1        0.565717    0.262322  train  0.565717
# ...

# %%
df['subset'] = 'test'
df
# Out:
#                    dataset      method preprocessing  n_neighbors  \
# 0                  Iemocap  base-multi           raw            2
# 1                  Iemocap  base-multi           raw            3
# 2                  Iemocap  base-multi           raw            4
# 3                  Iemocap  base-multi           raw            5
# 4                  Iemocap  base-multi           raw            6
# ...                    ...         ...           ...          ...
# 4657  English-Assembly-Six      binary  standardized           71
# 4658  English-Assembly-Six      binary  standardized           72
# 4659  English-Assembly-Six      binary  standardized           73
# 4660  English-Assembly-Six      binary  standardized           74
# 4661  English-Assembly-Six      binary  standardized           75
#
#       train_score  test_score subset     score
# 0        0.634721    0.242059   test  0.634721
# 1        0.565717    0.262322   test  0.565717
# ...

# %%
df['score'] = df['test_score']
df
# Out:
#                    dataset      method preprocessing  n_neighbors  \
# 0                  Iemocap  base-multi           raw            2
# 1                  Iemocap  base-multi           raw            3
# 2                  Iemocap  base-multi           raw            4
# 3                  Iemocap  base-multi           raw            5
# 4                  Iemocap  base-multi           raw            6
# ...                    ...         ...           ...          ...
# 4657  English-Assembly-Six      binary  standardized           71
# 4658  English-Assembly-Six      binary  standardized           72
# 4659  English-Assembly-Six      binary  standardized           73
# 4660  English-Assembly-Six      binary  standardized           74
# 4661  English-Assembly-Six      binary  standardized           75
#
#       train_score  test_score subset     score
# 0        0.634721    0.242059   test  0.242059
# 1        0.565717    0.262322   test  0.262322
# ...

# %%
df.to_csv('classifiers\\knn\\_knn_summarized_results_final_test.csv', index=False, sep=';')

# %%
train_df = pd.read_csv('classifiers\\knn\\_knn_summarized_results_final_train.csv', delimiter=';')
train_df
# Out:
#                    dataset      method preprocessing  n_neighbors  \
# 0                  Iemocap  base-multi           raw            2
# 1                  Iemocap  base-multi           raw            3
# 2                  Iemocap  base-multi           raw            4
# 3                  Iemocap  base-multi           raw            5
# 4                  Iemocap  base-multi           raw            6
# ...                    ...         ...           ...          ...
# 4657  English-Assembly-Six      binary  standardized           71
# 4658  English-Assembly-Six      binary  standardized           72
# 4659  English-Assembly-Six      binary  standardized           73
# 4660  English-Assembly-Six      binary  standardized           74
# 4661  English-Assembly-Six      binary  standardized           75
#
#       train_score  test_score subset     score
# 0        0.634721    0.242059  train  0.634721
# 1        0.565717    0.262322  train  0.565717
# ...

# %%
test_df = pd.read_csv('classifiers\\knn\\_knn_summarized_results_final_test.csv', delimiter=';')
test_df
# Out:
#                    dataset      method preprocessing  n_neighbors  \
# 0                  Iemocap  base-multi           raw            2
# 1                  Iemocap  base-multi           raw            3
# 2                  Iemocap  base-multi           raw            4
# 3                  Iemocap  base-multi           raw            5
# 4                  Iemocap  base-multi           raw            6
# ...                    ...         ...           ...          ...
# 4657  English-Assembly-Six      binary  standardized           71
# 4658  English-Assembly-Six      binary  standardized           72
# 4659  English-Assembly-Six      binary  standardized           73
# 4660  English-Assembly-Six      binary  standardized           74
# 4661  English-Assembly-Six      binary  standardized           75
#
#       train_score  test_score subset     score
# 0        0.634721    0.242059   test  0.242059
# 1        0.565717    0.262322   test  0.262322
# ...

# %%
final_df = pd.concat([train_df, test_df], ignore_index=True)
final_df
# Out:
#                    dataset      method preprocessing  n_neighbors  \
# 0                  Iemocap  base-multi           raw            2
# 1                  Iemocap  base-multi           raw            3
# 2                  Iemocap  base-multi           raw            4
# 3                  Iemocap  base-multi           raw            5
# 4                  Iemocap  base-multi           raw            6
# ...                    ...         ...           ...          ...
# 9319  English-Assembly-Six      binary  standardized           71
# 9320  English-Assembly-Six      binary  standardized           72
# 9321  English-Assembly-Six      binary  standardized           73
# 9322  English-Assembly-Six      binary  standardized           74
# 9323  English-Assembly-Six      binary  standardized           75
#
#       train_score  test_score subset     score
# 0        0.634721    0.242059  train  0.634721
# 1        0.565717    0.262322  train  0.565717
# ...

# %%
final_df.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-4f1c0f5dced7> in <module>
# ----> 1 final_df.summary()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'summary'

# %%
final_df.describe()
# Out:
#        n_neighbors  train_score   test_score        score
# count  9324.000000  9324.000000  9324.000000  9324.000000
# mean     38.500000     0.640006     0.603531     0.621768
# std      21.361155     0.153979     0.165347     0.160802
# min       2.000000     0.302778     0.230556     0.230556
# 25%      20.000000     0.552778     0.500000     0.527778
# 50%      38.500000     0.656703     0.625714     0.637985
# 75%      57.000000     0.740011     0.694030     0.716667
# max      75.000000     0.993327     0.992857     0.993327

# %%
final_df = final_df.drop(['train_score', 'test_score'], axis=1)
final_df
# Out:
#                    dataset      method preprocessing  n_neighbors subset  \
# 0                  Iemocap  base-multi           raw            2  train
# 1                  Iemocap  base-multi           raw            3  train
# 2                  Iemocap  base-multi           raw            4  train
# 3                  Iemocap  base-multi           raw            5  train
# 4                  Iemocap  base-multi           raw            6  train
# ...                    ...         ...           ...          ...    ...
# 9319  English-Assembly-Six      binary  standardized           71   test
# 9320  English-Assembly-Six      binary  standardized           72   test
# 9321  English-Assembly-Six      binary  standardized           73   test
# 9322  English-Assembly-Six      binary  standardized           74   test
# 9323  English-Assembly-Six      binary  standardized           75   test
#
#          score
# 0     0.634721
# 1     0.565717
# 2     0.544724
# 3     0.516977
# ...

# %%
summary = final_df.groupby(['dataset', 'method', 'preprocessing', 'subset']).max()

# %%
final_df
# Out:
#                    dataset      method preprocessing  n_neighbors subset  \
# 0                  Iemocap  base-multi           raw            2  train
# 1                  Iemocap  base-multi           raw            3  train
# 2                  Iemocap  base-multi           raw            4  train
# 3                  Iemocap  base-multi           raw            5  train
# 4                  Iemocap  base-multi           raw            6  train
# ...                    ...         ...           ...          ...    ...
# 9319  English-Assembly-Six      binary  standardized           71   test
# 9320  English-Assembly-Six      binary  standardized           72   test
# 9321  English-Assembly-Six      binary  standardized           73   test
# 9322  English-Assembly-Six      binary  standardized           74   test
# 9323  English-Assembly-Six      binary  standardized           75   test
#
#          score
# 0     0.634721
# 1     0.565717
# 2     0.544724
# 3     0.516977
# ...

# %%
final_df.to_csv('classifiers\\knn\\knn_summarized_results_final.csv', sep=';', index=False)

# %%
summary.to_csv('classifiers\\knn\\knn_summary.csv', sep=';', index=False)

# %%
df = pd.read_csv('classifiers\\knn\\knn_summarized_results_final.csv', delimiter=';')
df
# Out:
#                    dataset      method preprocessing  n_neighbors subset  \
# 0                  Iemocap  base-multi           raw            2  train
# 1                  Iemocap  base-multi           raw            3  train
# 2                  Iemocap  base-multi           raw            4  train
# 3                  Iemocap  base-multi           raw            5  train
# 4                  Iemocap  base-multi           raw            6  train
# ...                    ...         ...           ...          ...    ...
# 9319  English-Assembly-Six      binary  standardized           71   test
# 9320  English-Assembly-Six      binary  standardized           72   test
# 9321  English-Assembly-Six      binary  standardized           73   test
# 9322  English-Assembly-Six      binary  standardized           74   test
# 9323  English-Assembly-Six      binary  standardized           75   test
#
#          score
# 0     0.634721
# 1     0.565717
# 2     0.544724
# 3     0.516977
# ...

# %%
df = pd.read_csv('classifiers\\knn\\knn_summary.csv', delimiter=';')
df
# Out:
#      n_neighbors     score
# 0             75  0.318646
# 1             75  0.626053
# 2             75  0.321870
# 3             75  0.622290
# 4             75  0.486298
# ..           ...       ...
# 121           75  0.891325
# 122           75  0.821429
# 123           75  0.888942
# 124           75  0.992857
# 125           75  0.990944
#
# [126 rows x 2 columns]

# %%
summary
# Out:
#                                          n_neighbors     score
# dataset method     preprocessing subset
# Crema-D base-multi normalized    test             75  0.318646
#                                  train            75  0.626053
#                    raw           test             75  0.321870
#                                  train            75  0.622290
#                    standardized  test             75  0.486298
# ...                                              ...       ...
# TESS    first_try  normalized    train            75  0.891325
#                    raw           test             75  0.821429
#                                  train            75  0.888942
#                    standardized  test             75  0.992857
#                                  train            75  0.990944
#
# [126 rows x 2 columns]

# %%
summary.to_csv('classifiers\\knn\\knn_summary.csv', sep=';')

# %%
df = pd.read_csv('classifiers\\knn\\knn_summary.csv', delimiter=';')
df
# Out:
#      dataset      method preprocessing subset  n_neighbors     score
# 0    Crema-D  base-multi    normalized   test           75  0.318646
# 1    Crema-D  base-multi    normalized  train           75  0.626053
# 2    Crema-D  base-multi           raw   test           75  0.321870
# 3    Crema-D  base-multi           raw  train           75  0.622290
# 4    Crema-D  base-multi  standardized   test           75  0.486298
# ..       ...         ...           ...    ...          ...       ...
# 121     TESS   first_try    normalized  train           75  0.891325
# 122     TESS   first_try           raw   test           75  0.821429
# 123     TESS   first_try           raw  train           75  0.888942
# 124     TESS   first_try  standardized   test           75  0.992857
# 125     TESS   first_try  standardized  train           75  0.990944
#
# [126 rows x 6 columns]
