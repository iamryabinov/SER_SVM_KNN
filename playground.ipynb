# %%
import pandas as pd
import numpy as np

# %%
start_df = pd.read_csv('classifiers\\knn\\knn_summarized_results.csv', delimiter=';')
final_df = pd.read_csv('classifiers\\knn\\knn_summarized_results_final.csv', delimiter=';')
start_df.head(3)
# Out:
#    n_neighbors  train_score_raw  test_score_raw  train_score_normalized  \
# 0            2         0.634721        0.242059                0.626871
# 1            3         0.565717        0.262322                0.558781
# 2            4         0.544724        0.293538                0.534319
#
#    test_score_normalized  train_score_standardized  test_score_standardized  \
# 0               0.256298                  0.712486                 0.367470
# 1               0.264513                  0.650055                 0.396495
# 2               0.291347                  0.615005                 0.415663
#
#   method_name dataset_name
# 0  base-multi      Iemocap
# 1  base-multi      Iemocap
# 2  base-multi      Iemocap

# %%
final_df
# Out:
# Empty DataFrame
# Columns: [dataset, method, preprocessing, n_neighbors, train_score, test_score]
# Index: []

# %%
current_df = start_df.loc[(start_df['dataset_name'] == 'Iemocap') 
                          & (start_df['method_name'] == 'base-multi')]
current_df
# Out:
#     n_neighbors  train_score_raw  test_score_raw  train_score_normalized  \
# 0             2         0.634721        0.242059                0.626871
# 1             3         0.565717        0.262322                0.558781
# 2             4         0.544724        0.293538                0.534319
# 3             5         0.516977        0.294633                0.508397
# 4             6         0.490142        0.277108                0.488682
# ..          ...              ...             ...                     ...
# 69           71         0.362724        0.364184                0.357247
# 70           72         0.364184        0.359803                0.358342
# 71           73         0.364549        0.361446                0.361081
# 72           74         0.362541        0.357065                0.360533
# 73           75         0.361263        0.357065                0.359985
#
#     test_score_normalized  train_score_standardized  test_score_standardized  \
# ...

# %%
data = {
    'dataset': current_df['dataset_name'],
    'method': current_df['method_name'],
    'preprocessing': 'raw',
    'n_neighbors': current_df['n_neighbors'],
    'train_score': current_df['train_score_raw'],
    'test_score': current_df['test_score_raw']
}

# %%
df = pd.DataFrame(data)
df
# Out:
#     dataset      method preprocessing  n_neighbors  train_score  test_score
# 0   Iemocap  base-multi           raw            2     0.634721    0.242059
# 1   Iemocap  base-multi           raw            3     0.565717    0.262322
# 2   Iemocap  base-multi           raw            4     0.544724    0.293538
# 3   Iemocap  base-multi           raw            5     0.516977    0.294633
# 4   Iemocap  base-multi           raw            6     0.490142    0.277108
# ..      ...         ...           ...          ...          ...         ...
# 69  Iemocap  base-multi           raw           71     0.362724    0.364184
# 70  Iemocap  base-multi           raw           72     0.364184    0.359803
# 71  Iemocap  base-multi           raw           73     0.364549    0.361446
# 72  Iemocap  base-multi           raw           74     0.362541    0.357065
# 73  Iemocap  base-multi           raw           75     0.361263    0.357065
#
# [74 rows x 6 columns]
