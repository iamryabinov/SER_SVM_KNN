# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('datasets\\all_english\\six_discrete\\features\\_features_with_labels.csv', delimiter=';')
df
# Out:
#                             name label  frameTime  \
# 0      'Ses01F_impro01_F000_neu'   neu        0.0
# 1      'Ses01F_impro01_F001_neu'   neu        0.0
# 2      'Ses01F_impro01_F002_neu'   neu        0.0
# 3      'Ses01F_impro01_F005_neu'   neu        0.0
# 4      'Ses01F_impro01_F006_fru'   fru        0.0
# ...                          ...   ...        ...
# 19459           'YAF_youth_fear'   fea        0.0
# 19460          'YAF_youth_happy'   hap        0.0
# 19461        'YAF_youth_neutral'   neu        0.0
# 19462             'YAF_youth_ps'   sur        0.0
# 19463            'YAF_youth_sad'   sad        0.0
#
#        F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                               37.04012
# 1                               33.76131
# 2                               33.93212
# 3                               38.54665
# 4                               36.34007
# ...                                  ...
# 19459                           42.07449
# ...

# %%
df.groupby('label').mean()
# Out:
#        frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# label
# ang          0.0                          36.068450
# cal          0.0                          30.033557
# dis          0.0                          30.776861
# exc          0.0                          34.162224
# fea          0.0                          35.628682
# fru          0.0                          32.938407
# hap          0.0                          34.668098
# neu          0.0                          30.286296
# sad          0.0                          29.966055
# sur          0.0                          38.108957
#
#        F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# label
# ang                                  0.110596
# cal                                  0.098946
# dis                                  0.117909
# exc                                  0.144713
# fea                                  0.083289
# fru                                  0.120756
# ...

# %%
df = df.loc[(df['label'] == 'ang') | (df['label'] == 'dis') | (df['label'] == 'fea') | (df['label'] == 'hap') | (df['label'] == 'neu') | (df['label'] == 'sad')]
df.reset_index(drop=True, inplace=True)
df.groupby('label').count()
# Out:
#        name  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# label
# ang    3021       3021                               3021
# dis    1923       1923                               1923
# fea    1922       1922                               1922
# hap    2511       2511                               2511
# neu    3405       3405                               3405
# sad    2999       2999                               2999
#
#        F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# label
# ang                                      3021
# dis                                      1923
# fea                                      1922
# hap                                      2511
# neu                                      3405
# sad                                      2999
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# label
# ang                                          3021
# dis                                          1923
# ...
