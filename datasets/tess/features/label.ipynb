# %%
import pandas as pd
import numpy as np

# %%
features = pd.read_csv('features_with_labels.csv', delimiter=';')
features.head(100)
# Out:
#                   name      label  frameTime  \
# 0     'OAF_back_angry'      anger        0.0
# 1   'OAF_back_disgust'    disgust        0.0
# 2      'OAF_back_fear'       fear        0.0
# 3     'OAF_back_happy'  happiness        0.0
# 4   'OAF_back_neutral'    neutral        0.0
# ..                 ...        ...        ...
# 95       'OAF_calm_ps'   surprise        0.0
# 96      'OAF_calm_sad'    sadness        0.0
# 97    'OAF_came_angry'      anger        0.0
# 98  'OAF_came_disgust'    disgust        0.0
# 99     'OAF_came_fear'       fear        0.0
#
#     F0semitoneFrom27.5Hz_sma3nz_amean  F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                            36.83212                                0.121332
# 1                            32.76449                                0.083722
# 2                            40.83719                                0.035345
# 3                            37.33035                                0.139670
# ...

# %%
    features.loc[features['name'].str.contains('angry', case=True), 'label'] = 'ang'
    features.loc[features['name'].str.contains('disgust', case=True), 'label'] = 'dis'
    features.loc[features['name'].str.contains('fear', case=True), 'label'] = 'fea'
    features.loc[features['name'].str.contains('happy', case=True), 'label'] = 'hap'
    features.loc[features['name'].str.contains('neutral', case=True), 'label'] = 'neu'
    features.loc[features['name'].str.contains('sad', case=True), 'label'] = 'sad'
    features.loc[features['name'].str.contains('ps', case=True), 'label'] = 'sur'

# %%
features.groupby('label').count()
# Out:
#        name  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# label
# ang     399        399                                399
# dis     400        400                                400
# fea     399        399                                399
# hap     400        400                                400
# neu     400        400                                400
# sad     400        400                                400
# sur     400        400                                400
#
#        F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# label
# ang                                       399
# dis                                       400
# fea                                       399
# hap                                       400
# neu                                       400
# sad                                       400
# sur                                       400
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# label
# ...

# %%
features.to_csv('features_with_labels.csv', index=False, sep=';')
