# %%
import pandas as pd
import numpy as np

# %%
features = pd.read_csv('features_with_labels.csv', delimiter=';')
features.head(100)
# Out:
#                   name label  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0     'OAF_back_angry'   ang        0.0                           36.83212
# 1   'OAF_back_disgust'   dis        0.0                           32.76449
# 2      'OAF_back_fear'   fea        0.0                           40.83719
# 3     'OAF_back_happy'   hap        0.0                           37.33035
# 4   'OAF_back_neutral'   neu        0.0                           32.73508
# ..                 ...   ...        ...                                ...
# 95       'OAF_calm_ps'   sur        0.0                           36.24169
# 96      'OAF_calm_sad'   sad        0.0                           34.56355
# 97    'OAF_came_angry'   ang        0.0                           37.58490
# 98  'OAF_came_disgust'   dis        0.0                           33.44263
# 99     'OAF_came_fear'   fea        0.0                           41.43362
#
#     F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# ...

# %%
    features.loc[features['name'].str.contains('angry', case=True), 'label_2'] = 'neg'
    features.loc[features['name'].str.contains('disgust', case=True), 'label_2'] = 'neg'
    features.loc[features['name'].str.contains('fear', case=True), 'label_2'] = 'neg'
    features.loc[features['name'].str.contains('happy', case=True), 'label_2'] = 'pos'
    features.loc[features['name'].str.contains('neutral', case=True), 'label_2'] = 'neu'
    features.loc[features['name'].str.contains('sad', case=True), 'label_2'] = 'neg'
    features.loc[features['name'].str.contains('ps', case=True), 'label_2'] = 'pos'
    features
# Out:
#                      name label  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0        'OAF_back_angry'   ang        0.0                           36.83212
# 1      'OAF_back_disgust'   dis        0.0                           32.76449
# 2         'OAF_back_fear'   fea        0.0                           40.83719
# 3        'OAF_back_happy'   hap        0.0                           37.33035
# 4      'OAF_back_neutral'   neu        0.0                           32.73508
# ...                   ...   ...        ...                                ...
# 2793     'YAF_youth_fear'   fea        0.0                           42.07449
# 2794    'YAF_youth_happy'   hap        0.0                           39.42330
# 2795  'YAF_youth_neutral'   neu        0.0                           34.40434
# 2796       'YAF_youth_ps'   sur        0.0                           42.70466
# 2797      'YAF_youth_sad'   sad        0.0                           32.95188
#
# ...

# %%
features.groupby('label_2').count()
# Out:
#          name  label  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# label_2
# neg      1598   1598       1598                               1598
# neu       400    400        400                                400
# pos       800    800        800                                800
#
#          F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# label_2
# neg                                        1598
# neu                                         400
# pos                                         800
#
#          F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# label_2
# neg                                            1598
# neu                                             400
# pos                                             800
#
#          F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# label_2
# neg                                            1598
# neu                                             400
# pos                                             800
#
# ...

# %%
features.to_csv('features_with_labels.csv', index=False, sep=';')
