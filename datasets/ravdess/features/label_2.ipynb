# %%
import pandas as pd
import numpy as np

# %%
features = pd.read_csv('features_with_labels.csv', delimiter=';')
features
# Out:
#                         name label  frameTime  \
# 0     '03-01-01-01-01-01-01'   neu        0.0
# 1     '03-01-01-01-01-01-02'   neu        0.0
# 2     '03-01-01-01-01-01-03'   neu        0.0
# 3     '03-01-01-01-01-01-04'   neu        0.0
# 4     '03-01-01-01-01-01-05'   neu        0.0
# ...                      ...   ...        ...
# 1435  '03-01-08-02-02-02-20'   sur        0.0
# 1436  '03-01-08-02-02-02-21'   sur        0.0
# 1437  '03-01-08-02-02-02-22'   sur        0.0
# 1438  '03-01-08-02-02-02-23'   sur        0.0
# 1439  '03-01-08-02-02-02-24'   sur        0.0
#
#       F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                              24.26370
# 1                              36.79599
# 2                              29.88570
# 3                              37.43581
# 4                              25.34099
# ...                                 ...
# 1435                           39.35845
# 1436                           32.03861
# ...

# %%
features['label_2'] = features['label']
features
# Out:
#                         name label  frameTime  \
# 0     '03-01-01-01-01-01-01'   neu        0.0
# 1     '03-01-01-01-01-01-02'   neu        0.0
# 2     '03-01-01-01-01-01-03'   neu        0.0
# 3     '03-01-01-01-01-01-04'   neu        0.0
# 4     '03-01-01-01-01-01-05'   neu        0.0
# ...                      ...   ...        ...
# 1435  '03-01-08-02-02-02-20'   sur        0.0
# 1436  '03-01-08-02-02-02-21'   sur        0.0
# 1437  '03-01-08-02-02-02-22'   sur        0.0
# 1438  '03-01-08-02-02-02-23'   sur        0.0
# 1439  '03-01-08-02-02-02-24'   sur        0.0
#
#       F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                              24.26370
# 1                              36.79599
# 2                              29.88570
# 3                              37.43581
# 4                              25.34099
# ...                                 ...
# 1435                           39.35845
# 1436                           32.03861
# ...

# %%
a = features.groupby(['label']).count()
a
# Out:
#        name  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# label
# ang     192        192                                192
# cal     192        192                                192
# dis     192        192                                192
# fea     192        192                                192
# hap     192        192                                192
# neu      96         96                                 96
# sad     192        192                                192
# sur     192        192                                192
#
#        F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# label
# ang                                       192
# cal                                       192
# dis                                       192
# fea                                       192
# hap                                       192
# neu                                        96
# sad                                       192
# sur                                       192
#
# ...

# %%
features.loc[features['label'] == 'ang', 'label_2'] = 'neg'
features.loc[features['label'] == 'dis', 'label_2'] = 'neg'
features.loc[features['label'] == 'fea', 'label_2'] = 'neg'
features.loc[features['label'] == 'hap', 'label_2'] = 'pos'
features.loc[features['label'] == 'neu', 'label_2'] = 'neu'
features.loc[features['label'] == 'sad', 'label_2'] = 'neg'
features.loc[features['label'] == 'cal', 'label_2'] = 'pos'
features.loc[features['label'] == 'sur', 'label_2'] = 'pos'
features
# Out:
#                         name label  frameTime  \
# 0     '03-01-01-01-01-01-01'   neu        0.0
# 1     '03-01-01-01-01-01-02'   neu        0.0
# 2     '03-01-01-01-01-01-03'   neu        0.0
# 3     '03-01-01-01-01-01-04'   neu        0.0
# 4     '03-01-01-01-01-01-05'   neu        0.0
# ...                      ...   ...        ...
# 1435  '03-01-08-02-02-02-20'   sur        0.0
# 1436  '03-01-08-02-02-02-21'   sur        0.0
# 1437  '03-01-08-02-02-02-22'   sur        0.0
# 1438  '03-01-08-02-02-02-23'   sur        0.0
# 1439  '03-01-08-02-02-02-24'   sur        0.0
#
#       F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                              24.26370
# 1                              36.79599
# 2                              29.88570
# 3                              37.43581
# 4                              25.34099
# ...                                 ...
# 1435                           39.35845
# 1436                           32.03861
# ...

# %%
features.groupby(['label_2']).count()
# Out:
#          name  label  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# label_2
# neg       768    768        768                                768
# neu        96     96         96                                 96
# pos       576    576        576                                576
#
#          F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# label_2
# neg                                         768
# neu                                          96
# pos                                         576
#
#          F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# label_2
# neg                                             768
# neu                                              96
# pos                                             576
#
#          F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# label_2
# neg                                             768
# neu                                              96
# pos                                             576
#
# ...

# %%
features.to_csv('_features_with_labels.csv', index=False, sep=';')

# %%
features.loc[(features['label_2'] =='pos') | (features['label_2'] == 'neg')]
# Out:
#                         name label  frameTime  \
# 96    '03-01-02-01-01-01-01'   cal        0.0
# 97    '03-01-02-01-01-01-02'   cal        0.0
# 98    '03-01-02-01-01-01-03'   cal        0.0
# 99    '03-01-02-01-01-01-04'   cal        0.0
# 100   '03-01-02-01-01-01-05'   cal        0.0
# ...                      ...   ...        ...
# 1435  '03-01-08-02-02-02-20'   sur        0.0
# 1436  '03-01-08-02-02-02-21'   sur        0.0
# 1437  '03-01-08-02-02-02-22'   sur        0.0
# 1438  '03-01-08-02-02-02-23'   sur        0.0
# 1439  '03-01-08-02-02-02-24'   sur        0.0
#
#       F0semitoneFrom27.5Hz_sma3nz_amean  \
# 96                             24.89970
# 97                             36.13000
# 98                             24.80299
# 99                             36.18040
# 100                            24.15610
# ...                                 ...
# 1435                           39.35845
# 1436                           32.03861
# ...
