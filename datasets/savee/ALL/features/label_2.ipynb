# %%
import pandas as pd
import numpy as np

# %%
features = pd.read_csv('features_with_labels.csv', delimiter=';')
features
# Out:
#           name label  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0     'DC_a01'   ang        0.0                           32.28717
# 1     'DC_a02'   ang        0.0                           28.62288
# 2     'DC_a03'   ang        0.0                           32.75483
# 3     'DC_a04'   ang        0.0                           30.76265
# 4     'DC_a05'   ang        0.0                           32.73560
# ..         ...   ...        ...                                ...
# 475  'KL_su11'   sur        0.0                           27.10709
# 476  'KL_su12'   sur        0.0                           29.34474
# 477  'KL_su13'   sur        0.0                           29.01023
# 478  'KL_su14'   sur        0.0                           28.44299
# 479  'KL_su15'   sur        0.0                           28.73246
#
#      F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                  0.253556
# 1                                  0.083329
# ...

# %%
    features.loc[features['name'].str.contains('a', case=True), 'label_2'] = 'neg'
    features.loc[features['name'].str.contains('d', case=True), 'label_2'] = 'neg'
    features.loc[features['name'].str.contains('f', case=True), 'label_2'] = 'neg'
    features.loc[features['name'].str.contains('h', case=True), 'label_2'] = 'pos'
    features.loc[features['name'].str.contains('n', case=True), 'label_2'] = 'neu'
    features.loc[features['name'].str.contains('sa', case=True), 'label_2'] = 'neg'
    features.loc[features['name'].str.contains('su', case=True), 'label_2'] = 'pos'
    features
# Out:
#           name label  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0     'DC_a01'   ang        0.0                           32.28717
# 1     'DC_a02'   ang        0.0                           28.62288
# 2     'DC_a03'   ang        0.0                           32.75483
# 3     'DC_a04'   ang        0.0                           30.76265
# 4     'DC_a05'   ang        0.0                           32.73560
# ..         ...   ...        ...                                ...
# 475  'KL_su11'   sur        0.0                           27.10709
# 476  'KL_su12'   sur        0.0                           29.34474
# 477  'KL_su13'   sur        0.0                           29.01023
# 478  'KL_su14'   sur        0.0                           28.44299
# 479  'KL_su15'   sur        0.0                           28.73246
#
#      F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                  0.253556
# 1                                  0.083329
# ...

# %%
features
# Out:
#           name label  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0     'DC_a01'   ang        0.0                           32.28717
# 1     'DC_a02'   ang        0.0                           28.62288
# 2     'DC_a03'   ang        0.0                           32.75483
# 3     'DC_a04'   ang        0.0                           30.76265
# 4     'DC_a05'   ang        0.0                           32.73560
# ..         ...   ...        ...                                ...
# 475  'KL_su11'   sur        0.0                           27.10709
# 476  'KL_su12'   sur        0.0                           29.34474
# 477  'KL_su13'   sur        0.0                           29.01023
# 478  'KL_su14'   sur        0.0                           28.44299
# 479  'KL_su15'   sur        0.0                           28.73246
#
#      F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                  0.253556
# 1                                  0.083329
# ...

# %%
features.to_csv('_features_with_labels.csv', index=False, sep=';')
features
# Out:
#           name label  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0     'DC_a01'   ang        0.0                           32.28717
# 1     'DC_a02'   ang        0.0                           28.62288
# 2     'DC_a03'   ang        0.0                           32.75483
# 3     'DC_a04'   ang        0.0                           30.76265
# 4     'DC_a05'   ang        0.0                           32.73560
# ..         ...   ...        ...                                ...
# 475  'KL_su11'   sur        0.0                           27.10709
# 476  'KL_su12'   sur        0.0                           29.34474
# 477  'KL_su13'   sur        0.0                           29.01023
# 478  'KL_su14'   sur        0.0                           28.44299
# 479  'KL_su15'   sur        0.0                           28.73246
#
#      F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                  0.253556
# 1                                  0.083329
# ...
