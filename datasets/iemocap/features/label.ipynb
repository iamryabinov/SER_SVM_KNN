# %%
import pandas as pd
import numpy as np
import pickle

# %%
df = pd.read_csv('features_with_labels.csv', delimiter=';')
df
# Out:
#                               name label  frameTime  \
# 0        'Ses01F_impro01_F000_neu'   neu        0.0
# 1        'Ses01F_impro01_F001_neu'   neu        0.0
# 2        'Ses01F_impro01_F002_neu'   neu        0.0
# 3        'Ses01F_impro01_F005_neu'   neu        0.0
# 4        'Ses01F_impro01_F006_fru'   fru        0.0
# ...                            ...   ...        ...
# 7299  'Ses05M_script03_2_M041_ang'   ang        0.0
# 7300  'Ses05M_script03_2_M042_ang'   ang        0.0
# 7301  'Ses05M_script03_2_M043_ang'   ang        0.0
# 7302  'Ses05M_script03_2_M044_ang'   ang        0.0
# 7303  'Ses05M_script03_2_M045_ang'   ang        0.0
#
#       F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                              37.04012
# 1                              33.76131
# 2                              33.93212
# 3                              38.54665
# 4                              36.34007
# ...                                 ...
# 7299                           36.49042
# 7300                           39.28991
# 7301                           40.54793
# 7302                           40.63523
# 7303                           40.39804
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                   0.043453
# 1                                   0.028599
# 2                                   0.079872
# 3                                   0.093294
# 4                                   0.125629
# ...                                      ...
# 7299                                0.134295
# 7300                                0.096055
# 7301                                0.107257
# 7302                                0.116018
# 7303                                0.148550
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                       35.53110
# 1                                       32.78694
# 2                                       31.30519
# 3                                       35.40284
# 4                                       32.64409
# ...                                          ...
# 7299                                    32.35279
# 7300                                    36.36411
# 7301                                    36.65015
# 7302                                    36.89973
# 7303                                    36.62209
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                       36.89790
# 1                                       33.96196
# 2                                       32.70642
# 3                                       38.04982
# 4                                       36.01867
# ...                                          ...
# 7299                                    36.76859
# 7300                                    38.29396
# 7301                                    41.26639
# 7302                                    40.05107
# 7303                                    39.47769
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                       39.02742
# 1                                       34.71528
# 2                                       37.07990
# 3                                       41.97728
# 4                                       39.23974
# ...                                          ...
# 7299                                    41.53406
# 7300                                    41.28949
# 7301                                    44.63888
# 7302                                    43.22825
# 7303                                    45.77739
#
#       F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                     3.496323
# 1                                     1.928341
# 2                                     5.774717
# 3                                     6.574440
# 4                                     6.595650
# ...                                        ...
# 7299                                  9.181271
# 7300                                  4.925385
# 7301                                  7.988724
# 7302                                  6.328522
# 7303                                  9.155304
#
#       F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  ...  \
# 0                                        23.63756  ...
# 1                                         0.00000  ...
# 2                                        34.88018  ...
# 3                                        35.12406  ...
# 4                                       117.18410  ...
# ...                                           ...  ...
# 7299                                    201.24130  ...
# 7300                                     95.14951  ...
# 7301                                     50.80379  ...
# 7302                                    152.51540  ...
# 7303                                     66.72556  ...
#
#       slopeUV0-500_sma3nz_amean  slopeUV500-1500_sma3nz_amean  \
# 0                     -0.001585                      0.002005
# 1                      0.000189                      0.002216
# 2                     -0.002343                     -0.000944
# 3                      0.019407                     -0.005384
# 4                      0.011759                     -0.003597
# ...                         ...                           ...
# 7299                   0.002947                      0.002514
# 7300                   0.022777                     -0.007187
# 7301                   0.018675                      0.003977
# 7302                   0.025157                     -0.003925
# 7303                   0.003991                     -0.005942
#
#       spectralFluxUV_sma3nz_amean  loudnessPeaksPerSec  VoicedSegmentsPerSec  \
# 0                        0.029974             2.590674              1.063830
# 1                        0.051167             0.729927              0.757576
# 2                        0.025375             1.282051              0.977199
# 3                        0.157638             2.493766              3.282828
# 4                        0.164428             2.386117              2.631579
# ...                           ...                  ...                   ...
# 7299                     0.255013             3.276699              2.689487
# 7300                     0.586565             3.468208              2.380952
# 7301                     0.956627             3.603604              2.764977
# 7302                     0.695076             3.820225              2.954545
# 7303                     0.636651             3.338898              2.192243
#
#       MeanVoicedSegmentLengthSec  StddevVoicedSegmentLengthSec  \
# 0                       0.155000                      0.135000
# 1                       0.100000                      0.000000
# 2                       0.150000                      0.008165
# 3                       0.120000                      0.061269
# 4                       0.285833                      0.201761
# ...                          ...                           ...
# 7299                    0.175455                      0.122539
# 7300                    0.207500                      0.124574
# 7301                    0.211667                      0.096508
# 7302                    0.267692                      0.238010
# 7303                    0.306154                      0.184372
#
#       MeanUnvoicedSegmentLength  StddevUnvoicedSegmentLength  \
# 0                      0.506667                     0.347787
# 1                      0.595000                     0.065000
# 2                      0.846667                     0.950731
# 3                      0.175833                     0.261389
# 4                      0.095556                     0.109657
# ...                         ...                          ...
# 7299                   0.225294                     0.325325
# 7300                   0.192500                     0.169614
# 7301                   0.130000                     0.134288
# 7302                   0.075000                     0.028284
# 7303                   0.139167                     0.263105
#
#       equivalentSoundLevel_dBp
# 0                    -37.74199
# 1                    -35.05312
# 2                    -37.17597
# 3                    -23.20543
# 4                    -19.55981
# ...                        ...
# 7299                 -19.03220
# 7300                 -14.29124
# 7301                 -12.61142
# 7302                 -12.29261
# 7303                 -11.42488
#
# [7304 rows x 91 columns]

# %%
df = df[['name', 'label']]
df
# Out:
#                               name label
# 0        'Ses01F_impro01_F000_neu'   neu
# 1        'Ses01F_impro01_F001_neu'   neu
# 2        'Ses01F_impro01_F002_neu'   neu
# 3        'Ses01F_impro01_F005_neu'   neu
# 4        'Ses01F_impro01_F006_fru'   fru
# ...                            ...   ...
# 7299  'Ses05M_script03_2_M041_ang'   ang
# 7300  'Ses05M_script03_2_M042_ang'   ang
# 7301  'Ses05M_script03_2_M043_ang'   ang
# 7302  'Ses05M_script03_2_M044_ang'   ang
# 7303  'Ses05M_script03_2_M045_ang'   ang
#
# [7304 rows x 2 columns]

# %%
names = df['name'].values.tolist()
print
names2 = []
for name in names:
    try:
        name = name[1:-5]
        names2.append(name)
    except TypeError:
        names2.append(name)
df['name'] = names2

# %%
df.to_csv('name-label.csv', sep=';', index=False)

# %%
list = features['name'].values.tolist()

# %%
list = [item[1:-1] for item in list]
list

# %%
features['name'] = list
features

# %%
features.loc[features['name'] == 'Ses01F_impro01_F006_fru'].drop('name', axis=1).values

# %%
features

# %%
features.to_csv('egemaps.csv', index=False, sep=';')

# %%
features.loc[features['label'] == 'ang', 'label'] = 'anger'
features.loc[features['label'] == 'exc', 'label'] = 'excitement'
features.loc[features['label'] == 'fru', 'label'] = 'frustration'
features.loc[features['label'] == 'hap', 'label'] = 'happiness'
features.loc[features['label'] == 'neu', 'label'] = 'neutral'
features.loc[features['label'] == 'sad', 'label'] = 'sadness'
features

# %%
features.to_csv('features_with_labels.csv', index=False, sep=';')
features
