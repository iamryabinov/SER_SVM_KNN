# %%
import pandas as pd
import numpy as np

# %%
features = pd.read_csv('features_with_labels.csv', delimiter=';')
features
# Out:
#           name  label  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0    '03a01Fa'    NaN        0.0                           31.19023
# 1    '03a01Nc'    NaN        0.0                           26.68655
# 2    '03a01Wa'    NaN        0.0                           34.30344
# 3    '03a02Fc'    NaN        0.0                           37.58125
# 4    '03a02Nc'    NaN        0.0                           25.03913
# ..         ...    ...        ...                                ...
# 530  '16b10Lb'    NaN        0.0                           32.26835
# 531  '16b10Tb'    NaN        0.0                           34.41307
# 532  '16b10Td'    NaN        0.0                           31.22742
# 533  '16b10Wa'    NaN        0.0                           41.47187
# 534  '16b10Wb'    NaN        0.0                           43.25301
#
#      F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                  0.152486
# 1                                  0.308064
# ...

# %%
    features.loc[features['name'].str.contains('W', case=True), 'label'] = 'anger'
    features.loc[features['name'].str.contains('E', case=True), 'label'] = 'disgust'
    features.loc[features['name'].str.contains('A', case=True), 'label'] = 'fear'
    features.loc[features['name'].str.contains('F', case=True), 'label'] = 'happiness'
    features.loc[features['name'].str.contains('N', case=True), 'label'] = 'neutral'
    features.loc[features['name'].str.contains('T', case=True), 'label'] = 'sadness'
    features.loc[features['name'].str.contains('L', case=True), 'label'] = 'boredom'

# %%
features
# Out:
#           name      label  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0    '03a01Fa'  happiness        0.0                           31.19023
# 1    '03a01Nc'    neutral        0.0                           26.68655
# 2    '03a01Wa'      anger        0.0                           34.30344
# 3    '03a02Fc'  happiness        0.0                           37.58125
# 4    '03a02Nc'    neutral        0.0                           25.03913
# ..         ...        ...        ...                                ...
# 530  '16b10Lb'    boredom        0.0                           32.26835
# 531  '16b10Tb'    sadness        0.0                           34.41307
# 532  '16b10Td'    sadness        0.0                           31.22742
# 533  '16b10Wa'      anger        0.0                           41.47187
# 534  '16b10Wb'      anger        0.0                           43.25301
#
#      F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                  0.152486
# ...
