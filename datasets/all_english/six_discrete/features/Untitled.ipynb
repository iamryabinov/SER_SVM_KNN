# %%
import pandas as pd
import numpy as np

# %%
features = pd.read_csv('_features_with_labels.csv', delimiter=';')
features
# Out:
#                             name label  frameTime  \
# 0      'Ses01F_impro01_F000_neu'   neu        0.0
# 1      'Ses01F_impro01_F001_neu'   neu        0.0
# 2      'Ses01F_impro01_F002_neu'   neu        0.0
# 3      'Ses01F_impro01_F005_neu'   neu        0.0
# 4      'Ses01F_impro01_F006_fru'   fru        0.0
# ...                          ...   ...        ...
# 19459           'YAF_youth_fear'   fea        0.0
# 19460          'YAF_youth_happy'   hap        0.0
# 19461        'YAF_youth_neutral'   neu        0.0
# 19462             'YAF_youth_ps'   sur        0.0
# 19463            'YAF_youth_sad'   sad        0.0
#
#        F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                               37.04012
# 1                               33.76131
# 2                               33.93212
# 3                               38.54665
# 4                               36.34007
# ...                                  ...
# 19459                           42.07449
# ...

# %%
features.loc[(features['label_2'] == 'pos') | (features['label_2'] == 'neu'), 'label_2'] = 'not'
features
# Out:
#                             name label  frameTime  \
# 0      'Ses01F_impro01_F000_neu'   neu        0.0
# 1      'Ses01F_impro01_F001_neu'   neu        0.0
# 2      'Ses01F_impro01_F002_neu'   neu        0.0
# 3      'Ses01F_impro01_F005_neu'   neu        0.0
# 4      'Ses01F_impro01_F006_fru'   fru        0.0
# ...                          ...   ...        ...
# 19459           'YAF_youth_fear'   fea        0.0
# 19460          'YAF_youth_happy'   hap        0.0
# 19461        'YAF_youth_neutral'   neu        0.0
# 19462             'YAF_youth_ps'   sur        0.0
# 19463            'YAF_youth_sad'   sad        0.0
#
#        F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                               37.04012
# 1                               33.76131
# 2                               33.93212
# 3                               38.54665
# 4                               36.34007
# ...                                  ...
# 19459                           42.07449
# ...

# %%
a = features.groupby(['label_2']).count()
a
# Out:
#           name  label  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# label_2
# neg      11691  11691      11691                              11691
# not       7773   7773       7773                               7773
#
#          F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# label_2
# neg                                       11691
# not                                        7773
#
#          F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# label_2
# neg                                           11691
# not                                            7773
#
#          F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# label_2
# neg                                           11691
# not                                            7773
#
#          F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# label_2
# neg                                           11691
# not                                            7773
#
#          F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# label_2
# ...
