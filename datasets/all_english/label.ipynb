# %%
import pandas as pd
import numpy as np

# %%
features = pd.read_csv('features_with_labels.csv', delimiter=';')
features
# Out:
#                             name label  frameTime  \
# 0      'Ses01F_impro01_F000_neu'   neu        0.0
# 1      'Ses01F_impro01_F001_neu'   neu        0.0
# 2      'Ses01F_impro01_F002_neu'   neu        0.0
# 3      'Ses01F_impro01_F005_neu'   neu        0.0
# 4      'Ses01F_impro01_F006_fru'   fru        0.0
# ...                          ...   ...        ...
# 19459           'YAF_youth_fear'   fea        0.0
# 19460          'YAF_youth_happy'   hap        0.0
# 19461        'YAF_youth_neutral'   neu        0.0
# 19462             'YAF_youth_ps'   sur        0.0
# 19463            'YAF_youth_sad'   sad        0.0
#
#        F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                               37.04012
# 1                               33.76131
# 2                               33.93212
# 3                               38.54665
# 4                               36.34007
# ...                                  ...
# 19459                           42.07449
# ...

# %%
features.groupby(['label']).count()
# Out:
#        name  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# label
# ang    3021       3021                               3021
# cal     192        192                                192
# dis    1923       1923                               1923
# exc    1013       1013                               1013
# fea    1922       1922                               1922
# fru    1826       1826                               1826
# hap    2511       2511                               2511
# neu    3405       3405                               3405
# sad    2999       2999                               2999
# sur     652        652                                652
#
#        F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# label
# ang                                      3021
# cal                                       192
# dis                                      1923
# exc                                      1013
# fea                                      1922
# ...

# %%
features = features.loc[(features['label'] == 'ang') | (features['label'] == 'dis') | (features['label'] == 'fea') | (features['label'] == 'hap') | (features['label'] == 'neu') | (features['label'] == 'sad')]
features
# Out:
#                             name label  frameTime  \
# 0      'Ses01F_impro01_F000_neu'   neu        0.0
# 1      'Ses01F_impro01_F001_neu'   neu        0.0
# 2      'Ses01F_impro01_F002_neu'   neu        0.0
# 3      'Ses01F_impro01_F005_neu'   neu        0.0
# 9      'Ses01F_impro01_F012_ang'   ang        0.0
# ...                          ...   ...        ...
# 19458        'YAF_youth_disgust'   dis        0.0
# 19459           'YAF_youth_fear'   fea        0.0
# 19460          'YAF_youth_happy'   hap        0.0
# 19461        'YAF_youth_neutral'   neu        0.0
# 19463            'YAF_youth_sad'   sad        0.0
#
#        F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                               37.04012
# 1                               33.76131
# 2                               33.93212
# 3                               38.54665
# 9                               34.07828
# ...                                  ...
# 19458                           33.42944
# ...

# %%
features.groupby(['label']).count()
# Out:
#        name  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# label
# ang    3021       3021                               3021
# dis    1923       1923                               1923
# fea    1922       1922                               1922
# hap    2511       2511                               2511
# neu    3405       3405                               3405
# sad    2999       2999                               2999
#
#        F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# label
# ang                                      3021
# dis                                      1923
# fea                                      1922
# hap                                      2511
# neu                                      3405
# sad                                      2999
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# label
# ang                                          3021
# dis                                          1923
# ...

# %%
features.to_csv('six_discrete\\features_with_labels.csv', index=False, sep=';')
